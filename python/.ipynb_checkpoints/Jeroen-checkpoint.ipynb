# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
# nicer looking default plots
plt.style.use('bmh')
from scipy import optimize as opt
from scipy import special as sp
from scipy import misc
from scipy.linalg import det
from scipy.misc import factorial
import mpmath

# %%
def u(a,x):
    denominator = 1#2**(-1./4.-0.5*a)*sp.gamma(1/4.-0.5*a)
    return float(mpmath.pcfd(-a-1./2.,x)/denominator)

def dfunction(x,a,c,X):
    return u(a,np.sqrt(2/c)*(x+X))

def func(e_, eF, b, X):
    if isinstance(e_,float):
        e = e_
    else:
        e = e_[0]
    
    if abs(e)>1:
        return 1
    
    c = 2*eF/b
    ky = X/c
    
    ep = eF + e
    em = eF - e
    
    g = 1./(e+1j*np.sqrt(1-e**2))
    gc = 1./(e-1j*np.sqrt(1-e**2))
    
    lp = np.sqrt(1-ky**2+1j*np.sqrt(1-e**2)/eF)
    lm = np.sqrt(1-ky**2-1j*np.sqrt(1-e**2)/eF)
    
    chip = u(-ep/b, np.sqrt(2/c)*(-X))
    chim = u(-em/b, np.sqrt(2/c)*X)
    
    dchip = misc.derivative(dfunction,0,args=(-ep/b,c,-X))
    dchim = misc.derivative(dfunction,0,args=(-em/b,c,X))
    
    #dchip = np.sqrt(2/c)*du(-ep/b, np.sqrt(2/c)*(-X))
    #dchim = np.sqrt(2/c)*du(-em/b, np.sqrt(2/c)*X)
        
    matrix = np.array([[chip, 0, g, gc],
                       [0, chim, 1, 1],
                       [dchip, 0, 1j*g*lm, -1j*gc*lp],
                       [0, dchim, 1j*lm, -1j*lp]])
    D = det(matrix)
    
    return D.imag

# %%
N = 100
b = 0.5
eF = 10.
X = 0.1*np.sqrt(40.)

print('X',X)

e = np.linspace(0.,1.,N)
res = np.zeros(e.shape)

for i in range(N):
    res[i] = func(e[i], eF, b, X)

plt.plot(e,res)
plt.show()
# Out:
# X 0.632455532034

# %%
N = 500
n =5
eF = 10.
b = 0.5
e0 = np.linspace(0,1,n)

xmin = -7.5
xmax = 7.5
emin = 0
emax = 0.99

x = np.linspace(xmin,xmax,N)
e = np.zeros((n,N))

for i in range(N):
    X = x[i]*np.sqrt(40)
    for j in range(n):
        e[j][i] = opt.fsolve(func,e0[j],args=(eF,b,X))


for i in range(n):
    plt.plot(x,e[i][:],'.b')
plt.axis([xmin,xmax,emin,emax])
#plt.plot(x,e,'.')

plt.show()
# Out:
# C:\Users\Anna\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fac79231bd38> in <module>()
#      16     X = x[i]*np.sqrt(40)
#      17     for j in range(n):
# ---> 18         e[j][i] = opt.fsolve(func,e0[j],args=(eF,b,X))
#      19
#      20
#
# C:\Users\Anna\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     144                'diag': diag}
#     145
# --> 146     res = _root_hybr(func, x0, args, jac=fprime, **options)
#     147     if full_output:
#     148         x = res['x']
#
# C:\Users\Anna\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     222             maxfev = 200 * (n + 1)
#     223         retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
# --> 224                                  ml, mu, epsfcn, factor, diag)
#     225     else:
#     226         _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# <ipython-input-2-a4ae745b5329> in func(e_, eF, b, X)
#      30     chim = u(-em/b, np.sqrt(2/c)*X)
#      31
# ---> 32     dchip = misc.derivative(dfunction,0,args=(-ep/b,c,-X))
#      33     dchim = misc.derivative(dfunction,0,args=(-em/b,c,X))
#      34
#
# C:\Users\Anna\Anaconda3\lib\site-packages\scipy\misc\common.py in derivative(func, x0, dx, n, args, order)
#     246     ho = order >> 1
#     247     for k in range(order):
# --> 248         val += weights[k]*func(x0+(k-ho)*dx,*args)
#     249     return val / product((dx,)*n,axis=0)
#     250
#
# <ipython-input-2-a4ae745b5329> in dfunction(x, a, c, X)
#       4
#       5 def dfunction(x,a,c,X):
# ----> 6     return u(a,np.sqrt(2/c)*(x+X))
#       7
#       8 def func(e_, eF, b, X):
#
# <ipython-input-2-a4ae745b5329> in u(a, x)
#       1 def u(a,x):
#       2     denominator = 1#2**(-1./4.-0.5*a)*sp.gamma(1/4.-0.5*a)
# ----> 3     return float(mpmath.pcfd(-a-1./2.,x)/denominator)
#       4
#       5 def dfunction(x,a,c,X):
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\functions\orthogonal.py in pcfd(ctx, n, z, **kwargs)
#     116
#     117     """
# --> 118     return ctx.hypercomb(lambda: _hermite_param(ctx, n, z, 1), [], **kwargs)
#     119
#     120 @defun
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#      77             orig2 = ctx.prec
#      78             params = orig_params[:]
# ---> 79             terms = function(*params)
#      80             if verbose:
#      81                 print()
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\functions\orthogonal.py in <lambda>()
#     116
#     117     """
# --> 118     return ctx.hypercomb(lambda: _hermite_param(ctx, n, z, 1), [], **kwargs)
#     119
#     120 @defun
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\functions\orthogonal.py in _hermite_param(ctx, n, z, parabolic_cylinder)
#      43     nw = ctx.fneg(w, exact=True)
#      44     if can_use_2f0:
# ---> 45         T1 = [2, w], [n, n], [], [], [q*n, q*(n-1)], [], nrw2
#      46         terms = [T1]
#      47     else:
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\ctx_mp_python.py in __sub__(self, other)
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\libmp\libmpf.py in mpf_sub(s, t, prec, rnd)
#     772     """Return the difference of two raw mpfs, s-t. This function is
#     773     simply a wrapper of mpf_add that changes the sign of t."""
# --> 774     return mpf_add(s, t, prec, rnd, 1)
#     775
#     776 def mpf_sum(xs, prec=0, rnd=round_fast, absolute=False):
#
# C:\Users\Anna\Anaconda3\lib\site-packages\mpmath\libmp\libmpf.py in mpf_add(s, t, prec, rnd, _sub)
#     738                         ssign = 1
#     739                 bc = bitcount(man)
# --> 740                 return normalize1(ssign, man, sexp, bc, prec or bc, rnd)
#     741         # Equal exponents; no shifting necessary
#     742         if ssign == tsign:
#
# KeyboardInterrupt:

# %%
a = 18.5
x = np.linspace(-8,10,100)
y = np.zeros(x.shape)
z = np.zeros(x.shape)
for i in range(100):
    y[i] = mpmath.pcfd(a,x[i])
    z[i] = sp.pbdv(a,x[i])[0]
    
plt.plot(x,y)
plt.show()
plt.plot(x,z)
plt.show()
